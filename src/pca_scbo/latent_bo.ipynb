# %%
import os, math, warnings
import time

import numpy as np
import torch, gpytorch
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, KernelPCA

warnings.filterwarnings("ignore", category=UserWarning)
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def set_global_seed(seed):
    import random
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


print("Device:", device)
# Out:
# Device: cuda

# %%
import numpy as np


class SpeedReducerProblem:
    def __init__(self, enforce_integer_teeth=True):
        self.enforce_integer_teeth = enforce_integer_teeth
        self.lb = np.array([2.6, 0.7, 17.0, 7.3, 7.3, 2.9, 5.0], dtype=np.float64)
        self.ub = np.array([3.6, 0.8, 28.0, 8.3, 8.3, 3.9, 5.5], dtype=np.float64)
        self.dim = 7
        self.n_constraints = 11
        self.f_star_ref = 2996.3482

    def coerce_shape(self, X):
        X = np.asarray(X, dtype=np.float64)
        was_1d = (X.ndim == 1)
        if was_1d: X = X[None, :]
        assert X.shape[-1] == 7, "expected last dimension to be 7."
        return X, was_1d

    def project_to_bounds(self, X):
        return np.clip(X, self.lb, self.ub)

    def evaluate(self, X):
        X, was_1d = self.coerce_shape(X)
        X = self.project_to_bounds(X).copy()
        if self.enforce_integer_teeth:
            X[:, 2] = np.rint(X[:, 2])
        x1, x2, x3, x4, x5, x6, x7 = [X[:, i] for i in range(7)]
        f = (0.7854 * x1 * x2 ** 2 * (3.3333 * x3 ** 2 + 14.9334 * x3 - 43.0934)
             - 1.508 * x1 * (x6 ** 2 + x7 ** 2)
             + 7.4777 * (x6 ** 3 + x7 ** 3)
             + 0.7854 * (x4 * x6 ** 2 + x5 * x7 ** 2))
        g = np.empty((X.shape[0], 11), dtype=np.float64)
        g[:, 0] = 27.0 / (x1 * x2 ** 2 * x3) - 1.0
        g[:, 1] = 397.5 / (x1 * x2 ** 2 * x3 ** 2) - 1.0
        g[:, 2] = 1.93 * x4 ** 3 / (x2 * x3 * x6 ** 4) - 1.0
        g[:, 3] = 1.93 * x5 ** 3 / (x2 * x3 * x7 ** 4) - 1.0
        g[:, 4] = np.sqrt((745.0 * x4 / (x2 * x3)) ** 2 + 16.9e6) / (0.1 * x6 ** 3) - 1100.0
        g[:, 5] = np.sqrt((745.0 * x5 / (x2 * x3)) ** 2 + 157.5e6) / (0.1 * x7 ** 3) - 850.0
        g[:, 6] = x2 * x3 - 40.0
        g[:, 7] = 5.0 - x1 / x2
        g[:, 8] = x1 / x2 - 12.0
        g[:, 9] = 1.5 * x6 + 1.9 - x4
        g[:, 10] = 1.1 * x7 + 1.9 - x5
        if was_1d: return f[0], g[0]
        return f, g

    def is_feasible(self, X):
        _, g = self.evaluate(X)
        return np.all(g <= 0.0, axis=-1)

    def sample_lhs(self, n, rng=None):
        if rng is None: rng = np.random.default_rng()
        d = self.dim
        cut = np.linspace(0, 1, n + 1)
        a, b = cut[:-1], cut[1:]
        u = rng.random((n, d))
        pts = a[:, None] + (b - a)[:, None] * u
        X = np.empty_like(pts)
        for j in range(d):
            X[:, j] = pts[rng.permutation(n), j]
        X = self.lb + X * (self.ub - self.lb)
        if self.enforce_integer_teeth:
            X[:, 2] = np.rint(X[:, 2])
        return X

# %%
def standardize(y_np):
    y_np = np.asarray(y_np, dtype=np.float64).reshape(-1, 1)
    mu = float(y_np.mean())
    sd = float(y_np.std() + 1e-12)
    y_std = (y_np - mu) / sd
    return y_std.ravel(), mu, sd


class ExactGP(gpytorch.models.ExactGP):
    def __init__(self, X, y, likelihood):
        super().__init__(X, y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(ard_num_dims=X.shape[-1])
        )

    def forward(self, x):
        mean = self.mean_module(x)
        cov = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean, cov)


def fit_gp(X_np, y_np, iters=100, lr=0.05):
    y_std, mu, sd = standardize(y_np)
    X_t = torch.as_tensor(X_np, dtype=torch.float64, device=device)
    y_t = torch.as_tensor(y_std, dtype=torch.float64, device=device)

    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)
    likelihood.noise_covar.register_constraint("raw_noise", gpytorch.constraints.GreaterThan(1e-6))
    model = ExactGP(X_t, y_t, likelihood).to(device)

    model.train()
    likelihood.train()
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for _ in range(iters):
        opt.zero_grad()
        with gpytorch.settings.cholesky_jitter(1e-5):
            out = model(X_t)
            loss = -mll(out, y_t)
        loss.backward()
        opt.step()

    model.eval()
    likelihood.eval()
    model._y_mu, model._y_sd = mu, sd
    return model, likelihood


def best_feasible_value(f_hist, C_hist):
    feas = np.all(C_hist <= 0.0, axis=1)
    return np.min(f_hist[feas]) if np.any(feas) else np.nan


def least_violation_index(C_hist):
    viol = np.clip(C_hist, 0.0, None).sum(axis=1)
    return int(np.argmin(viol))


def posterior_mean_std(model, X_t):
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        post = model(X_t)
        mean = post.mean
        std = post.variance.clamp_min(1e-12).sqrt()
    return mean, std

# %%
class TrustRegion:
    def __init__(self, lb, ub, init_frac=0.8, min_frac=0.05, max_frac=1.0,
                 grow=1.6, shrink=0.5, succ_tol=3, fail_tol=3, rng=None):
        self.lb = lb.astype(np.float32)
        self.ub = ub.astype(np.float32)
        self.center = (self.lb + self.ub) / 2.0
        self.frac = init_frac
        self.min_frac, self.max_frac = min_frac, max_frac
        self.grow, self.shrink = grow, shrink
        self.succ_tol, self.fail_tol = succ_tol, fail_tol
        self.succ = 0
        self.fail = 0
        self.rng = np.random.default_rng() if rng is None else rng

    def set_center(self, x_c):
        self.center = x_c.astype(np.float32)

    def sample(self, n_cand):
        halfspan = 0.5 * self.frac * (self.ub - self.lb)
        lo = np.maximum(self.center - halfspan, self.lb)
        hi = np.minimum(self.center + halfspan, self.ub)
        U = self.rng.random((n_cand, len(self.lb))).astype(np.float32)
        return lo + U * (hi - lo)

    def step(self, success):
        if success:
            self.succ += 1
            self.fail = 0
            if self.succ >= self.succ_tol:
                self.frac = min(self.max_frac, self.frac * self.grow);
                self.succ = 0
        else:
            self.fail += 1
            self.succ = 0
            if self.fail >= self.fail_tol:
                self.frac = max(self.min_frac, self.frac * self.shrink);
                self.fail = 0


def cheap_filter(problem, n_try=200000, rng=None):
    if rng is None: rng = np.random.default_rng()
    lb, ub = problem.lb, problem.ub
    X = lb + rng.random((n_try, problem.dim)) * (ub - lb)
    if problem.enforce_integer_teeth: X[:, 2] = np.rint(X[:, 2])
    x1, x2, x3, x4, x5, x6, x7 = [X[:, i] for i in range(7)]
    mask = (
            (x2 * x3 <= 40.0) & # gear ratio
            (x1 / x2 >= 5.0) & # face width vs module
            (x1 / x2 <= 12.0) & # face width vs module
            (1.5 * x6 + 1.9 <= x4) # shaft geometry
    )
    return X[mask]


def find_feasible_seed(problem, max_batches=5, per_batch=50000, verbose=True):
    tried = 0
    for b in range(max_batches):
        cand = cheap_filter(problem, n_try=per_batch)
        tried += per_batch
        if cand.size == 0:
            if verbose: print(f"[seed] batch {b + 1}: 0 survivors")
            continue
        _, G = problem.evaluate(cand)
        feas = np.all(G <= 0.0, axis=1)
        if np.any(feas):
            if verbose: print(f"[seed] found feasible after ~{tried} draws")
            return cand[feas][0]
        else:
            if verbose: print(f"[seed] batch {b + 1}: 0 feasible among {len(cand)}")
    if verbose: print("[seed] no feasible seed found")
    return None


@torch.no_grad()
def pick_candidate_feasibility_first(models_c, cand_t):
    normal = torch.distributions.Normal(0.0, 1.0)
    log_pof = torch.zeros(cand_t.shape[0], dtype=cand_t.dtype, device=cand_t.device)
    for mc in models_c:
        mu, sd = posterior_mean_std(mc, cand_t)
        z = -mu / sd
        log_pof = log_pof + normal.log_cdf(z)
    return torch.argmax(log_pof)

# %%
def build_models_scbo(X, f, C):
    mf, _ = fit_gp(X, f)
    models_c = []
    for i in range(C.shape[1]):
        mc, _ = fit_gp(X, C[:, i])
        models_c.append(mc)
    reducer = None
    return mf, models_c, reducer


class PCAReducer:
    def __init__(self, n_components):
        self.pca = PCA(n_components=n_components)

    def fit_transform(self, C):
        Z = self.pca.fit_transform(C)
        return Z

    def transform(self, C):
        return self.pca.transform(C)

    def inverse_transform(self, Z):
        return self.pca.inverse_transform(Z)


class KPCAReducer:
    def __init__(self, n_components, gamma=0.1):
        self.kpca = KernelPCA(n_components=n_components, kernel='rbf',
                              gamma=gamma, fit_inverse_transform=True)

    def fit_transform(self, C):
        return self.kpca.fit_transform(C)

    def transform(self, C):
        return self.kpca.transform(C)

    def inverse_transform(self, Z):
        return self.kpca.inverse_transform(Z)


def build_models_pca(X, f, C, n_components=4):
    reducer = PCAReducer(n_components)
    Z = reducer.fit_transform(C)
    mf, _ = fit_gp(X, f)
    models_z = []
    for i in range(Z.shape[1]):
        mz, _ = fit_gp(X, Z[:, i])
        models_z.append(mz)
    return mf, models_z, reducer


def build_models_kpca(X, f, C, n_components=4, gamma=0.1):
    reducer = KPCAReducer(n_components, gamma=gamma)
    Z = reducer.fit_transform(C)
    mf, _ = fit_gp(X, f)
    models_z = []
    for i in range(Z.shape[1]):
        mz, _ = fit_gp(X, Z[:, i])
        models_z.append(mz)
    return mf, models_z, reducer


@torch.no_grad()
def pick_candidate_cts(model_f, models_c_or_z, cand_t, reducer=None):
    f_samp = model_f(cand_t).sample()
    c_cols = [mc(cand_t).sample().unsqueeze(-1) for mc in models_c_or_z]
    Z_samp = torch.cat(c_cols, dim=-1)
    if reducer is not None:
        Z_np = Z_samp.cpu().numpy()
        C_np = reducer.inverse_transform(Z_np)
        C_samp = torch.as_tensor(C_np, dtype=cand_t.dtype, device=cand_t.device)
    else:
        C_samp = Z_samp

    feas = torch.all(C_samp <= 0.0, dim=-1)
    if feas.any():
        idx = torch.argmin(f_samp[feas])
        best_idx = torch.nonzero(feas, as_tuple=False).squeeze(1)[idx]
    else:
        viol = torch.clamp(C_samp, min=0.0).sum(dim=-1)
        best_idx = torch.argmin(viol)
    return best_idx

# %%
def run_bo(method="scbo", seed=42, n_init=20, iters=100, n_cand=4096,
           n_components=4, kpca_gamma=0.1, verbose=True,
           enforce_integer_teeth=True, try_seed_feasible=True):
    set_global_seed(seed)
    problem = SpeedReducerProblem(enforce_integer_teeth=enforce_integer_teeth)

    X = problem.sample_lhs(n_init, rng=np.random.default_rng(seed))
    f_list, C_list = [], []
    for x in X:
        f_i, g_i = problem.evaluate(x)
        f_list.append(f_i)
        C_list.append(g_i)
    f_vals = np.array(f_list, dtype=np.float64)
    C_vals = np.array(C_list, dtype=np.float64)

    feas = np.all(C_vals <= 0.0, axis=1)
    if (not np.any(feas)) and try_seed_feasible:
        x_seed = find_feasible_seed(problem, max_batches=5, per_batch=60000, verbose=verbose)
        if x_seed is not None:
            f_seed, g_seed = problem.evaluate(x_seed)
            X = np.vstack([X, x_seed])
            f_vals = np.append(f_vals, f_seed)
            C_vals = np.vstack([C_vals, g_seed])
            if verbose: print("[seed] appended one feasible seed")

    feas = np.all(C_vals <= 0.0, axis=1)
    if np.any(feas):
        inc = X[feas][np.argmin(f_vals[feas])]
    else:
        inc = X[least_violation_index(C_vals)]
    tr = TrustRegion(problem.lb, problem.ub, init_frac=0.8)
    tr.set_center(inc.astype(np.float32))

    curr_best = inc
    best_hist = []

    for t in range(iters):
        if verbose:
            print(f"{method.upper()} iter {t + 1}/{iters} | TR frac={tr.frac:.3f} | Current Best - {best_feasible_value(f_vals, C_vals):.3f}")

        if method == "scbo":
            mf, mcs, reducer = build_models_scbo(X, f_vals, C_vals)
        elif method == "pca":
            mf, mcs, reducer = build_models_pca(X, f_vals, C_vals, n_components=n_components)
        elif method == "kpca":
            mf, mcs, reducer = build_models_kpca(X, f_vals, C_vals, n_components=n_components, gamma=kpca_gamma)
        else:
            raise ValueError("method must be 'scbo', 'pca', or 'kpca'")

        have_feas = np.any(np.all(C_vals <= 0.0, axis=1))
        n_cand_this = n_cand if have_feas else max(n_cand, 8192)

        cand_np = tr.sample(n_cand_this)
        cand_t = torch.tensor(cand_np, dtype=torch.float64, device=device)
        if problem.enforce_integer_teeth:
            cand_t[:, 2] = torch.round(cand_t[:, 2])

        with torch.no_grad():
            if not have_feas:
                best_idx = pick_candidate_feasibility_first(mcs, cand_t)
            else:
                best_idx = pick_candidate_cts(mf, mcs, cand_t, reducer=reducer)
            x_next = cand_t[best_idx].cpu().numpy()

        f_next, g_next = problem.evaluate(x_next)
        X = np.vstack([X, x_next])
        f_vals = np.append(f_vals, f_next)
        C_vals = np.vstack([C_vals, g_next])

        prev_best = best_feasible_value(f_vals[:-1], C_vals[:-1])
        curr_best = best_feasible_value(f_vals, C_vals)
        success = (not np.isnan(curr_best)) and (np.isnan(prev_best) or curr_best < prev_best - 1e-12)
        tr.step(success)

        feas = np.all(C_vals <= 0.0, axis=1)
        if np.any(feas):
            inc = X[feas][np.argmin(f_vals[feas])]
        else:
            inc = X[least_violation_index(C_vals)]
        tr.set_center(inc.astype(np.float32))

        best_hist.append(curr_best)

    return {
        "X": X, "f": f_vals, "C": C_vals, "best_hist": np.array(best_hist, float),
        "problem": problem
    }

# %%
seed = 12345
n_init = 20
iters = 100
n_cand = 4096
g_comp = 4
gamma = 0.2

scbo_start_time = time.time()
print("=== SCBO ===")
res_scbo = run_bo("scbo", seed=seed, n_init=n_init, iters=iters, n_cand=n_cand)
scbo_end_pca_start_time = time.time()

print("\n=== PCA-GP SCBO ===")
res_pca = run_bo("pca", seed=seed, n_init=n_init, iters=iters, n_cand=n_cand, n_components=g_comp)
pca_end_kpca_start_time = time.time()
print("\n=== kPCA-GP SCBO ===")
res_kpca = run_bo("kpca", seed=seed, n_init=n_init, iters=iters, n_cand=n_cand,
                  n_components=g_comp, kpca_gamma=gamma)
kpca_end_time = time.time()

def plot_convergence(*pairs, f_star=2996.3482):
    plt.figure(figsize=(7, 4))
    for name, res in pairs:
        y = res["best_hist"]
        x = np.arange(1, len(y) + 1)
        m = ~np.isnan(y)
        plt.plot(x[m], y[m], lw=2, label=name)
    plt.axhline(f_star, ls="--", c="k", lw=1.2, label="$f^*$≈{:.2f}".format(f_star))
    plt.xlabel("Evaluations")
    plt.ylabel("Best feasible f")
    plt.title("Speed Reducer — Convergence (single seed)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()


plot_convergence(
    ("SCBO", res_scbo),
    ("PCA-GP SCBO (g=4)", res_pca),
    ("kPCA-GP SCBO (g=4)", res_kpca),
    f_star=res_scbo["problem"].f_star_ref
)

print("Final best (SCBO):     ", np.nanmin(res_scbo["best_hist"]))
print("Final best (PCA-GP):   ", np.nanmin(res_pca["best_hist"]))
print("Final best (kPCA-GP):  ", np.nanmin(res_kpca["best_hist"]))

print("==" * 60)

print("Time taken (SCBO):     ", scbo_end_pca_start_time - scbo_start_time)
print("Time taken (PCA-GP):   ", pca_end_kpca_start_time - scbo_end_pca_start_time)
print("Time taken (kPCA-GP):  ", kpca_end_time - pca_end_kpca_start_time)
# Out:
# === SCBO ===
# [seed] found feasible after ~60000 draws
# [seed] appended one feasible seed
# SCBO iter 1/100 | TR frac=0.800 | Current Best - 3200.867
# SCBO iter 2/100 | TR frac=0.800 | Current Best - 3200.867
# SCBO iter 3/100 | TR frac=0.800 | Current Best - 3200.867
# SCBO iter 4/100 | TR frac=0.400 | Current Best - 3200.867
# SCBO iter 5/100 | TR frac=0.400 | Current Best - 3200.867
# SCBO iter 6/100 | TR frac=0.400 | Current Best - 3200.867
# SCBO iter 7/100 | TR frac=0.200 | Current Best - 3200.867
# SCBO iter 8/100 | TR frac=0.200 | Current Best - 3200.867
# SCBO iter 9/100 | TR frac=0.200 | Current Best - 3200.867
# SCBO iter 10/100 | TR frac=0.100 | Current Best - 3200.867
# SCBO iter 11/100 | TR frac=0.100 | Current Best - 3200.867
# SCBO iter 12/100 | TR frac=0.100 | Current Best - 3200.867
# SCBO iter 13/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 14/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 15/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 16/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 17/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 18/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 19/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 20/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 21/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 22/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 23/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 24/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 25/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 26/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 27/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 28/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 29/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 30/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 31/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 32/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 33/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 34/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 35/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 36/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 37/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 38/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 39/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 40/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 41/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 42/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 43/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 44/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 45/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 46/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 47/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 48/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 49/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 50/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 51/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 52/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 53/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 54/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 55/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 56/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 57/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 58/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 59/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 60/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 61/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 62/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 63/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 64/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 65/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 66/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 67/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 68/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 69/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 70/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 71/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 72/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 73/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 74/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 75/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 76/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 77/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 78/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 79/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 80/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 81/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 82/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 83/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 84/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 85/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 86/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 87/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 88/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 89/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 90/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 91/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 92/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 93/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 94/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 95/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 96/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 97/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 98/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 99/100 | TR frac=0.050 | Current Best - 3200.867
# SCBO iter 100/100 | TR frac=0.050 | Current Best - 3200.867
#
# === PCA-GP SCBO ===
# [seed] found feasible after ~60000 draws
# [seed] appended one feasible seed
# PCA iter 1/100 | TR frac=0.800 | Current Best - 4152.591
# PCA iter 2/100 | TR frac=0.800 | Current Best - 4152.591
# PCA iter 3/100 | TR frac=0.800 | Current Best - 4152.591
# PCA iter 4/100 | TR frac=0.400 | Current Best - 4152.591
# PCA iter 5/100 | TR frac=0.400 | Current Best - 4152.591
# PCA iter 6/100 | TR frac=0.400 | Current Best - 4152.591
# PCA iter 7/100 | TR frac=0.200 | Current Best - 4152.591
# PCA iter 8/100 | TR frac=0.200 | Current Best - 4152.591
# PCA iter 9/100 | TR frac=0.200 | Current Best - 4152.591
# PCA iter 10/100 | TR frac=0.100 | Current Best - 4152.591
# PCA iter 11/100 | TR frac=0.100 | Current Best - 4152.591
# PCA iter 12/100 | TR frac=0.100 | Current Best - 4152.591
# PCA iter 13/100 | TR frac=0.050 | Current Best - 4152.591
# PCA iter 14/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 15/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 16/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 17/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 18/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 19/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 20/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 21/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 22/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 23/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 24/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 25/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 26/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 27/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 28/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 29/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 30/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 31/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 32/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 33/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 34/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 35/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 36/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 37/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 38/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 39/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 40/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 41/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 42/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 43/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 44/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 45/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 46/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 47/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 48/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 49/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 50/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 51/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 52/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 53/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 54/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 55/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 56/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 57/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 58/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 59/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 60/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 61/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 62/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 63/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 64/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 65/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 66/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 67/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 68/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 69/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 70/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 71/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 72/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 73/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 74/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 75/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 76/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 77/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 78/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 79/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 80/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 81/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 82/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 83/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 84/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 85/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 86/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 87/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 88/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 89/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 90/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 91/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 92/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 93/100 | TR frac=0.050 | Current Best - 4109.632
# PCA iter 94/100 | TR frac=0.050 | Current Best - 4071.680
# PCA iter 95/100 | TR frac=0.050 | Current Best - 4071.680
# PCA iter 96/100 | TR frac=0.050 | Current Best - 4071.680
# PCA iter 97/100 | TR frac=0.050 | Current Best - 4071.680
# PCA iter 98/100 | TR frac=0.050 | Current Best - 4071.680
# PCA iter 99/100 | TR frac=0.050 | Current Best - 4071.680
# PCA iter 100/100 | TR frac=0.050 | Current Best - 4071.680
#
# === kPCA-GP SCBO ===
# [seed] found feasible after ~60000 draws
# [seed] appended one feasible seed
# KPCA iter 1/100 | TR frac=0.800 | Current Best - 4724.059
# KPCA iter 2/100 | TR frac=0.800 | Current Best - 4724.059
# KPCA iter 3/100 | TR frac=0.800 | Current Best - 4724.059
# KPCA iter 4/100 | TR frac=0.400 | Current Best - 4724.059
# KPCA iter 5/100 | TR frac=0.400 | Current Best - 4724.059
# KPCA iter 6/100 | TR frac=0.400 | Current Best - 4724.059
# KPCA iter 7/100 | TR frac=0.400 | Current Best - 4231.074
# KPCA iter 8/100 | TR frac=0.400 | Current Best - 4231.074
# KPCA iter 9/100 | TR frac=0.400 | Current Best - 4231.074
# KPCA iter 10/100 | TR frac=0.200 | Current Best - 4231.074
# KPCA iter 11/100 | TR frac=0.200 | Current Best - 4231.074
# KPCA iter 12/100 | TR frac=0.200 | Current Best - 4231.074
# KPCA iter 13/100 | TR frac=0.100 | Current Best - 4231.074
# KPCA iter 14/100 | TR frac=0.100 | Current Best - 4231.074
# KPCA iter 15/100 | TR frac=0.100 | Current Best - 4024.014
# KPCA iter 16/100 | TR frac=0.100 | Current Best - 3780.048
# KPCA iter 17/100 | TR frac=0.100 | Current Best - 3780.048
# KPCA iter 18/100 | TR frac=0.100 | Current Best - 3773.296
# KPCA iter 19/100 | TR frac=0.100 | Current Best - 3719.421
# KPCA iter 20/100 | TR frac=0.100 | Current Best - 3719.421
# KPCA iter 21/100 | TR frac=0.100 | Current Best - 3718.752
# KPCA iter 22/100 | TR frac=0.100 | Current Best - 3718.752
# KPCA iter 23/100 | TR frac=0.100 | Current Best - 3710.588
# KPCA iter 24/100 | TR frac=0.100 | Current Best - 3710.482
# KPCA iter 25/100 | TR frac=0.160 | Current Best - 3476.616
# KPCA iter 26/100 | TR frac=0.160 | Current Best - 3476.616
# KPCA iter 27/100 | TR frac=0.160 | Current Best - 3476.616
# KPCA iter 28/100 | TR frac=0.080 | Current Best - 3476.616
# KPCA iter 29/100 | TR frac=0.080 | Current Best - 3476.616
# KPCA iter 30/100 | TR frac=0.080 | Current Best - 3476.616
# KPCA iter 31/100 | TR frac=0.050 | Current Best - 3476.616
# KPCA iter 32/100 | TR frac=0.050 | Current Best - 3476.616
# KPCA iter 33/100 | TR frac=0.050 | Current Best - 3476.616
# KPCA iter 34/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 35/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 36/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 37/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 38/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 39/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 40/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 41/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 42/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 43/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 44/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 45/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 46/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 47/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 48/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 49/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 50/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 51/100 | TR frac=0.050 | Current Best - 3457.496
# KPCA iter 52/100 | TR frac=0.050 | Current Best - 3452.718
# KPCA iter 53/100 | TR frac=0.050 | Current Best - 3452.718
# KPCA iter 54/100 | TR frac=0.050 | Current Best - 3440.747
# KPCA iter 55/100 | TR frac=0.050 | Current Best - 3440.747
# KPCA iter 56/100 | TR frac=0.050 | Current Best - 3440.747
# KPCA iter 57/100 | TR frac=0.050 | Current Best - 3440.747
# KPCA iter 58/100 | TR frac=0.050 | Current Best - 3432.570
# KPCA iter 59/100 | TR frac=0.050 | Current Best - 3432.570
# KPCA iter 60/100 | TR frac=0.050 | Current Best - 3432.570
# KPCA iter 61/100 | TR frac=0.050 | Current Best - 3432.570
# KPCA iter 62/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 63/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 64/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 65/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 66/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 67/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 68/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 69/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 70/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 71/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 72/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 73/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 74/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 75/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 76/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 77/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 78/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 79/100 | TR frac=0.050 | Current Best - 3430.721
# KPCA iter 80/100 | TR frac=0.050 | Current Best - 3427.996
# KPCA iter 81/100 | TR frac=0.050 | Current Best - 3427.996
# KPCA iter 82/100 | TR frac=0.050 | Current Best - 3427.996
# KPCA iter 83/100 | TR frac=0.050 | Current Best - 3427.996
# KPCA iter 84/100 | TR frac=0.050 | Current Best - 3427.996
# KPCA iter 85/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 86/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 87/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 88/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 89/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 90/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 91/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 92/100 | TR frac=0.050 | Current Best - 3426.467
# KPCA iter 93/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 94/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 95/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 96/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 97/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 98/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 99/100 | TR frac=0.050 | Current Best - 3419.001
# KPCA iter 100/100 | TR frac=0.050 | Current Best - 3419.001
# Final best (SCBO):      3200.866707102114
# Final best (PCA-GP):    4071.6796077586464
# Final best (kPCA-GP):   3419.0007175360965
# Time taken (SCBO):      342.7810306549072
# Time taken (PCA-GP):    142.14116740226746
# Time taken (kPCA-GP):   163.3507490158081
